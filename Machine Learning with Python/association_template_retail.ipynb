# %% [markdown]
#  This is a notebook template developed following teacher's indications

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori

# %% [markdown]
# ## Import data

# %%
df = pd.read_excel('./data/summary_transactions.xlsx', header = None)
df.head()
# Out:
#                                   0                           1    \
# 0  WHITE HANGING HEART T-LIGHT HOLDER         WHITE METAL LANTERN
# 1       ASSORTED COLOUR BIRD ORNAMENT  POPPY'S PLAYHOUSE BEDROOM
# 2           ALARM CLOCK BAKELIKE PINK   ALARM CLOCK BAKELIKE RED
# 3     PAPER CHAIN KIT 50'S CHRISTMAS                          NaN
# 4               EDWARDIAN PARASOL RED  RETRO COFFEE MUGS ASSORTED
#
#                               2                                    3    \
# 0  CREAM CUPID HEARTS COAT HANGER  KNITTED UNION FLAG HOT WATER BOTTLE
# 1       POPPY'S PLAYHOUSE KITCHEN    FELTCRAFT PRINCESS CHARLOTTE DOLL
# 2      ALARM CLOCK BAKELIKE GREEN      PANDA AND BUNNIES STICKER SHEET
# 3                             NaN                                  NaN
# 4             SAVE THE PLANET MUG       VINTAGE BILLBOARD DRINK ME MUG
#
#                                4                                   5    \
# 0   RED WOOLLY HOTTIE WHITE HEART.        SET 7 BABUSHKA NESTING BOXES
# 1          IVORY KNITTED MUG COSY   BOX OF 6 ASSORTED COLOUR TEASPOONS
# 2                 STARS GIFT TAPE          INFLATABLE POLITICAL GLOBE
# 3                              NaN                                 NaN
# 4  VINTAGE BILLBOARD LOVE/HATE MUG  WOOD 2 DRAWER CABINET WHITE FINISH
#
#                                   6                                  7    \
# 0   GLASS STAR FROSTED T-LIGHT HOLDER             HAND WARMER UNION JACK
# 1       BOX OF VINTAGE JIGSAW BLOCKS      BOX OF VINTAGE ALPHABET BLOCKS
# 2  VINTAGE HEADS AND TAILS CARD GAME     SET/2 RED RETROSPOT TEA TOWELS
# 3                                 NaN                                NaN
# 4   WOOD S/3 CABINET ANT WHITE FINISH  WOODEN PICTURE FRAME WHITE FINISH
#
#                                    8                         9    ...  472  \
# 0            HAND WARMER RED POLKA DOT                       NaN  ...  NaN
# 1             HOME BUILDING BLOCK WORD  LOVE BUILDING BLOCK WORD  ...  NaN
# 2  ROUND SNACK BOXES SET OF4 WOODLAND        SPACEBOY LUNCH BOX   ...  NaN
# 3                                  NaN                       NaN  ...  NaN
# 4          WOODEN FRAME ANTIQUE WHITE                        NaN  ...  NaN
#
#    473  474  475  476  477  478  479  480  481
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 482 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                                     0                                 1    \
# 0    WHITE HANGING HEART T-LIGHT HOLDER               WHITE METAL LANTERN
# 1         ASSORTED COLOUR BIRD ORNAMENT        POPPY'S PLAYHOUSE BEDROOM
# 2             ALARM CLOCK BAKELIKE PINK         ALARM CLOCK BAKELIKE RED
# 3       PAPER CHAIN KIT 50'S CHRISTMAS                                NaN
# 4                 EDWARDIAN PARASOL RED        RETRO COFFEE MUGS ASSORTED
# ..                                  ...                               ...
# 371            SILK PURSE BABUSHKA BLUE                               NaN
# 372         CHRISTMAS LIGHTS 10 SANTAS          SET OF 6 T-LIGHTS SNOWMEN
# 373     IVORY HANGING DECORATION  HEART          PACK OF 12 SKULL TISSUES
# 374     HOT WATER BOTTLE I AM SO POORLY  RETROSPOT HEART HOT WATER BOTTLE
# 375           SWEETHEART WIRE WALL TIDY         HI TEC ALPINE HAND WARMER
#
#                                      2                                    3    \
# 0         CREAM CUPID HEARTS COAT HANGER  KNITTED UNION FLAG HOT WATER BOTTLE
# 1              POPPY'S PLAYHOUSE KITCHEN    FELTCRAFT PRINCESS CHARLOTTE DOLL
# 2             ALARM CLOCK BAKELIKE GREEN      PANDA AND BUNNIES STICKER SHEET
# 3                                    NaN                                  NaN
# 4                    SAVE THE PLANET MUG       VINTAGE BILLBOARD DRINK ME MUG
# ..                                   ...                                  ...
# 371                                  NaN                                  NaN
# 372               HAND WARMER UNION JACK       FELTCRAFT PRINCESS OLIVIA DOLL
# 373                  LUNCH BAG CARS BLUE  ASSORTED TUTTI FRUTTI  FOB NOTEBOOK
# 374  15CM CHRISTMAS GLASS BALL 20 LIGHTS                   TOOL BOX SOFT TOY
# 375        SET OF 20 KIDS COOKIE CUTTERS             LOVE HEART POCKET WARMER
#
#                                  4                                   5    \
# 0     RED WOOLLY HOTTIE WHITE HEART.        SET 7 BABUSHKA NESTING BOXES
# 1            IVORY KNITTED MUG COSY   BOX OF 6 ASSORTED COLOUR TEASPOONS
# 2                   STARS GIFT TAPE          INFLATABLE POLITICAL GLOBE
# 3                                NaN                                 NaN
# 4    VINTAGE BILLBOARD LOVE/HATE MUG  WOOD 2 DRAWER CABINET WHITE FINISH
# ..                               ...                                 ...
# 371                              NaN                                 NaN
# 372     FELTCRAFT PRINCESS LOLA DOLL   FELTCRAFT PRINCESS CHARLOTTE DOLL
# 373             SANDWICH BATH SPONGE     PAPER CHAIN KIT 50'S CHRISTMAS
# 374       CHOCOLATE HOT WATER BOTTLE   HOT WATER BOTTLE TEA AND SYMPATHY
# 375     PINK HEART SHAPE PHOTO FRAME       HAND WARMER SCOTTY DOG DESIGN
#
#                                     6                                  7    \
# 0     GLASS STAR FROSTED T-LIGHT HOLDER             HAND WARMER UNION JACK
# 1         BOX OF VINTAGE JIGSAW BLOCKS      BOX OF VINTAGE ALPHABET BLOCKS
# 2    VINTAGE HEADS AND TAILS CARD GAME     SET/2 RED RETROSPOT TEA TOWELS
# 3                                   NaN                                NaN
# 4     WOOD S/3 CABINET ANT WHITE FINISH  WOODEN PICTURE FRAME WHITE FINISH
# ..                                  ...                                ...
# 371                                 NaN                                NaN
# 372  PINK CREAM FELT CRAFT TRINKET BOX                                 NaN
# 373   PAPER CHAIN KIT VINTAGE CHRISTMAS                     KEY FOB , SHED
# 374               HEART OF WICKER SMALL     CHRISTMAS CRAFT TREE TOP ANGEL
# 375     PAPER CHAIN KIT 50'S CHRISTMAS             DOLLY HONEYCOMB GARLAND
#
#                                      8                               9    ...  \
# 0              HAND WARMER RED POLKA DOT                             NaN  ...
# 1               HOME BUILDING BLOCK WORD        LOVE BUILDING BLOCK WORD  ...
# 2    ROUND SNACK BOXES SET OF4 WOODLAND              SPACEBOY LUNCH BOX   ...
# 3                                    NaN                             NaN  ...
# 4            WOODEN FRAME ANTIQUE WHITE                              NaN  ...
# ..                                   ...                             ...  ...
# 371                                  NaN                             NaN  ...
# 372                                  NaN                             NaN  ...
# 373          PAPER POCKET TRAVELING FAN    LADIES & GENTLEMEN METAL SIGN  ...
# 374       CHRISTMAS CRAFT LITTLE FRIENDS                             NaN  ...
# 375           HEART FILIGREE DOVE  SMALL  ROSE FOLKART HEART DECORATIONS  ...
#
#      472  473  474  475  476  477  478  479  480  481
# 0    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 371  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 372  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 373  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 374  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 375  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [376 rows x 482 columns]>

# %% [markdown]
# ## Pre-processing

# %%
records = []
for i in range(0, df.shape[0]):
    records.append([str(df.values[i, j]) for j in range(0, df.shape[1])])

# %% [markdown]
# ## Algorithm definition APRIORI
# ### Threshold definition

# %%
min_n = 2

# Calculate support. Suppose we have data from a 7 day (week) range, and we want products bought at least 3 times a day:
min_day = 3
range_data = 7
min_support = min_day * range_data / len(df)

min_confidence = 0.2
min_lift = 3

# %% [markdown]
# ### Algorithm execution

# %%
association_rules = apriori(records, min_support=min_support, min_confidence=min_confidence, min_lift=min_lift, min_length=min_n)
association_rules = list(association_rules)

# %%
len(association_rules)
# Out:
# 13

# %%
for item in association_rules:
    # first index of the inner list
    pair = item[0]
    items = [x for x in pair]
    # second index of the inner list
    support = item[1]

    print(f"Rule: {items[0]} -> {items[1]}\nSupport: {support}")
    print(f"Confidence: {item[2][0][2]}\nLift: {item[2][0][3]}")
    print(f"------------------------------")
# Out:
# Rule: HAND WARMER OWL DESIGN -> HAND WARMER BIRD DESIGN
# Support: 0.05851063829787234
# Confidence: 0.6111111111111112
# Lift: 4.888888888888889
# ------------------------------
# Rule: HAND WARMER SCOTTY DOG DESIGN -> HAND WARMER BIRD DESIGN
# Support: 0.05585106382978723
# Confidence: 0.5833333333333333
# Lift: 4.984848484848484
# ------------------------------
# Rule: HAND WARMER RED RETROSPOT -> HAND WARMER OWL DESIGN
# Support: 0.06648936170212766
# Confidence: 0.5319148936170213
# Lift: 5.405405405405405
# ------------------------------
# Rule: HAND WARMER SCOTTY DOG DESIGN -> HAND WARMER OWL DESIGN
# Support: 0.0851063829787234
# Confidence: 0.6808510638297872
# Lift: 5.818181818181818
# ------------------------------
# Rule: HAND WARMER SCOTTY DOG DESIGN -> HAND WARMER RED RETROSPOT
# Support: 0.05851063829787234
# Confidence: 0.5945945945945946
# Lift: 5.081081081081082
# ------------------------------
# Rule: HAND WARMER SCOTTY DOG DESIGN -> HAND WARMER UNION JACK
# Support: 0.05585106382978723
# Confidence: 0.47727272727272724
# Lift: 5.127272727272727
# ------------------------------
# Rule: PAPER CHAIN KIT 50'S CHRISTMAS  -> PAPER CHAIN KIT VINTAGE CHRISTMAS
# Support: 0.05851063829787234
# Confidence: 0.55
# Lift: 5.302564102564103
# ------------------------------
# Rule: nan -> HAND WARMER OWL DESIGN
# Support: 0.05585106382978723
# Confidence: 0.5833333333333333
# Lift: 4.768115942028985
# ------------------------------
# Rule: nan -> HAND WARMER RED RETROSPOT
# Support: 0.06648936170212766
# Confidence: 0.5319148936170213
# Lift: 5.405405405405405
# ------------------------------
# Rule: nan -> HAND WARMER SCOTTY DOG DESIGN
# Support: 0.08244680851063829
# Confidence: 0.6595744680851063
# Lift: 5.767441860465116
# ------------------------------
# Rule: nan -> HAND WARMER SCOTTY DOG DESIGN
# Support: 0.05851063829787234
# Confidence: 0.5945945945945946
# Lift: 5.199245757385293
# ------------------------------
# Rule: nan -> HAND WARMER SCOTTY DOG DESIGN
# Support: 0.05585106382978723
# Confidence: 0.47727272727272724
# Lift: 5.127272727272727
# ------------------------------
# Rule: nan -> PAPER CHAIN KIT 50'S CHRISTMAS
# Support: 0.05851063829787234
# Confidence: 0.55
# Lift: 5.442105263157895
# ------------------------------
